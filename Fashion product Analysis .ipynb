# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Data cleaning

# %%
df=pd.read_csv(r'D:\fashion_products.csv',encoding='unicode escape')

# %%
df
# Out:
#      User ID  Product ID Product Name   Brand         Category  Price  \
# 0         19           1        Dress  Adidas    Men's Fashion     40
# 1         97           2        Shoes     H&M  Women's Fashion     82
# 2         25           3        Dress  Adidas  Women's Fashion     44
# 3         57           4        Shoes    Zara    Men's Fashion     23
# 4         79           5      T-shirt  Adidas    Men's Fashion     79
# ..       ...         ...          ...     ...              ...    ...
# 995       20         996        Shoes    Zara  Women's Fashion     55
# 996       42         997      Sweater    Nike    Kids' Fashion     13
# 997        9         998      Sweater    Zara    Men's Fashion     47
# 998        8         999      T-shirt    Zara  Women's Fashion     68
# 999       91        1000        Shoes  Adidas  Women's Fashion     79
#
#        Rating   Color Size
# 0    1.043159   Black   XL
# 1    4.026416   Black    L
# 2    3.337938  Yellow   XL
# ...

# %%
df.columns
# Out:
# Index(['User ID', 'Product ID', 'Product Name', 'Brand', 'Category', 'Price',
#        'Rating', 'Color', 'Size'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   User ID       1000 non-null   int64
#  1   Product ID    1000 non-null   int64
#  2   Product Name  1000 non-null   object
#  3   Brand         1000 non-null   object
#  4   Category      1000 non-null   object
#  5   Price         1000 non-null   int64
#  6   Rating        1000 non-null   float64
#  7   Color         1000 non-null   object
#  8   Size          1000 non-null   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 70.4+ KB

# %%
pd.isnull(df).sum()
# Out:
# User ID         0
# Product ID      0
# Product Name    0
# Brand           0
# Category        0
# Price           0
# Rating          0
# Color           0
# Size            0
# dtype: int64

# %%
df['Rating']=df['Rating'].astype('int') #to change the dtype of rating column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   User ID       1000 non-null   int64
#  1   Product ID    1000 non-null   int64
#  2   Product Name  1000 non-null   object
#  3   Brand         1000 non-null   object
#  4   Category      1000 non-null   object
#  5   Price         1000 non-null   int64
#  6   Rating        1000 non-null   int32
#  7   Color         1000 non-null   object
#  8   Size          1000 non-null   object
# dtypes: int32(1), int64(3), object(5)
# memory usage: 66.5+ KB

# %%
df.columns
# Out:
# Index(['User ID', 'Product ID', 'Product Name', 'Brand', 'Category', 'Price',
#        'Rating', 'Color', 'Size'],
#       dtype='object')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
ax=sns.countplot(x="Product Name",data=df,)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_gen=df.groupby(['Product Name'],as_index=False)['Price'].sum().sort_values('Price',ascending=False )
sns.barplot(x='Product Name', y= 'Price',data=sales_gen)
# Out:
# <Axes: xlabel='Product Name', ylabel='Price'>

# %% [markdown]
# ## From above graph most selling product are Jeans.

# %%
sales_brand=df.groupby(['Brand'],as_index=False)['Price'].sum().sort_values('Price',ascending=False )
sns.barplot(x='Brand', y= 'Price',data=sales_brand)
# Out:
# <Axes: xlabel='Brand', ylabel='Price'>

# %% [markdown]
# ## Top 3 selling brand are Nike, H&M and Zara respectively

# %%
ax=sns.countplot(x="Rating",data=df,)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_brand=df.groupby(['Brand'],as_index=False)['Rating'].sum().sort_values('Rating',ascending=False )
sns.barplot(x='Brand', y= 'Rating',data=sales_brand)
# Out:
# <Axes: xlabel='Brand', ylabel='Rating'>

# %% [markdown]
# # Most likable products by customers are Nike

# %%
df.columns
# Out:
# Index(['User ID', 'Product ID', 'Product Name', 'Brand', 'Category', 'Price',
#        'Rating', 'Color', 'Size'],
#       dtype='object')

# %%
sales_brand=df.groupby(['Category','Product Name'],as_index=False)['Price'].sum().sort_values('Price',ascending=False )
sns.barplot(x='Category', y= 'Price',data=sales_brand ,errorbar=None)
# Out:
# <Axes: xlabel='Category', ylabel='Price'>

# %%
sales_brand=df.groupby(['Category','Brand'],as_index=False)['Price'].sum().sort_values('Price',ascending=False )
sns.barplot(x='Brand', y= 'Price',data=sales_brand,errorbar=None)
# Out:
# <Axes: xlabel='Brand', ylabel='Price'>

# %% [markdown]
# # From above most selling category kids fashion category by Nike

# %%
sales_brand=df.groupby(['Product Name','Size'],as_index=False)['Price'].sum().sort_values('Price',ascending=False )
sns.barplot(x='Product Name', y= 'Price',data=sales_brand ,errorbar=None)
# Out:
# <Axes: xlabel='Product Name', ylabel='Price'>

# %%
df.columns
# Out:
# Index(['User ID', 'Product ID', 'Product Name', 'Brand', 'Category', 'Price',
#        'Rating', 'Color', 'Size'],
#       dtype='object')

# %%
sales_brand=df.groupby(['Color'],as_index=False)['Price'].sum().sort_values('Price',ascending=False )
sns.barplot(x='Color', y= 'Price',data=sales_brand)
# Out:
# <Axes: xlabel='Color', ylabel='Price'>

# %%
##most selling colors are white ,yellow and blue

# %%
sales_brand=df.groupby(['Size','Brand'],as_index=False)['Price'].sum().sort_values('Price',ascending=False)
sns.barplot(x='Size', y= 'Price',data=sales_brand,errorbar=None)
# Out:
# <Axes: xlabel='Size', ylabel='Price'>

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# # Most selling product is jeans.
# # Most likable brand is nike.
# # Most selling  category kids fashion category.
# # Most selling sizes XL, M & L.
